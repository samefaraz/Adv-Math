# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
alpha_ = 0.002
delta_x = 0.01
delta_t = 1

# %%
A = np.zeros(98)
B = np.zeros(98)
C = np.zeros(98)
T = np.zeros(100)
D = np.zeros(98)

# %%
    for i in range(98):
        A[i] = (alpha_*(delta_t/(delta_x**2)))
        B[i] = -(1+((2*alpha_*delta_t)/(delta_x**2)))
        C[i] = (alpha_*(delta_t/(delta_x**2)))
        T[i+1] = 20
        D[i] = -T[i+1]

# %%
T[[0, -1]] = 10, 30

# %%
D[0] = D[0] - A[0]*T[0]
D[-1] = D[-1] - C[-1]*T[-1]

# %%
T = np.zeros(100)
for i in range(98):
    T[i+1] = 20
T[[0, -1]] = 25, 30
fig = plt.figure()
for n in range(1000):
    if n % 5 == 0:
        plt.plot(T)
    alpha_ = 0.002
    delta_x = 0.01
    delta_t = 1
    A = np.zeros(98)
    B = np.zeros(98)
    C = np.zeros(98)
    D = np.zeros(98)
    for i in range(98):
        A[i] = (alpha_*(delta_t/(delta_x**2)))
        B[i] = -(1+((2*alpha_*delta_t)/(delta_x**2)))
        C[i] = (alpha_*(delta_t/(delta_x**2)))
        D[i] = -T[i+1]
    D[0] = D[0] - A[0]*T[0]
    D[-1] = D[-1] - C[-1]*T[-1]
    for i in range(98):
        if i == 0:
            C[i] = C[i]/B[i]
            D[i] = D[i]/B[i]
            B[i] = 1
            A[i] = 0
        elif i <= 97 and i >= 0:
            C[i] = (C[i]/(B[i]-(C[i-1]*A[i])))
            D[i] = (D[i]-(D[i-1]*A[i]))/(B[i]-(C[i-1]*A[i]))
            B[i] = 1
            A[i] = 0
#             print(D)
        elif i == 97:
            C[i] = 0
            D[i] = (D[i]-(D[i-1]*A[i]))/(B[i]-(C[i-1]*A[i]))
            B[i] = 1
            A[i] = 0
#     plt.plot(D)

    
    for j in range(97,-1,-1):
        if j == 97:
            T[j+1] = D[j]
        elif j<=96 and j>=0:
            T[j+1] = (D[j] - (C[j]*T[j+2]))
        
        
#     plt.plot(A)
#     plt.plot(C)
#     plt.plot(D)

plt.show()

# %%
plt.plot(T)

# %%
T
# Out:
# array([ 1.00000000e+001,  0.00000000e+000, -1.10000000e+001,
#         3.81550075e+001, -7.61615171e+005,  4.03852768e+006,
#        -4.03363514e+010,  3.12905447e+011, -2.08478710e+015,
#         2.31583344e+016, -1.15774033e+020,  1.82344087e+021,
#        -7.29423343e+024,  1.62338403e+026, -5.41106225e+029,
#         1.70203640e+031, -4.86004997e+034,  2.16431494e+036,
#        -5.40104482e+039,  3.41051644e+041, -7.54924768e+044,
#         6.75759809e+046, -1.34162669e+050,  1.69600723e+052,
#        -3.04505127e+055,  5.38661301e+057, -8.79683151e+060,
#         2.14154296e+063, -3.19278107e+066,  1.04185868e+069,
#        -1.42059424e+072,  5.98521010e+074, -7.46702941e+077,
#         3.87123914e+080, -4.41819771e+083,  2.66788436e+086,
#        -2.78581662e+089,  1.85388254e+092, -1.77333806e+095,
#         1.23872700e+098, -1.08780891e+101,  7.67700731e+103,
#        -6.20018799e+106,  4.29810641e+109, -3.19675510e+112,
#         2.13474769e+115, -1.46696637e+118,  9.33060383e+120,
#        -5.95805234e+123,  3.59242059e+126, -2.14529588e+129,
#         1.22526511e+132, -6.88257833e+134,  3.72790428e+137,
#        -1.97927596e+140,  1.01871834e+143, -5.13270288e+145,
#         2.51598157e+148, -1.20696472e+151,  5.64750935e+153,
#        -2.58684704e+156,  1.15793139e+159, -5.07684660e+161,
#         2.17844731e+164, -9.16224851e+166,  3.77593608e+169,
#        -1.52640849e+172,  6.05243030e+174, -2.35577256e+177,
#         9.00197290e+179, -3.37906916e+182,  1.24624155e+185,
#        -4.51812092e+187,  1.61053721e+190, -5.64693536e+192,
#         1.94803425e+195, -6.61410678e+197,  2.21079939e+200,
#        -7.27718900e+202,  2.35952144e+205, -7.53789929e+207,
#         2.37327596e+210, -7.36593571e+212,  2.25418594e+215,
#        -6.80355321e+217,  2.02563524e+220, -5.95060728e+222,
#         1.72514660e+225, -4.93678870e+227,  1.39476845e+230,
#        -3.89119086e+232,  1.07217688e+235, -2.91831951e+237,
#         7.84798378e+239, -2.08553206e+242,  5.47748920e+244,
#        -1.42207897e+247,  3.64954629e+249, -9.38154559e+251,
#         3.00000000e+001])
